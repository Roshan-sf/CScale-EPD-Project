# %%
import requests
import os

url = "https://buildingtransparency.org/api/rest-auth/login"

querystring = {"tokenless":"false"}

payload = {
    "username": os.getenv("OPENEPD_USER"),
    "password": os.getenv("OPENEPD_PW")
}
headers = {
    "Content-Type": "application/json",
    "Accept": "application/json"
}

response = requests.post(url, json=payload, headers=headers, params=querystring)

response_data = response.json()

#print(response_data)

auth_key = response.json()['key']

print(auth_key)
# Out:
# kWa4JuigK7uhlp6C5uXRTv1fKZtL0L

# %%
headers = {
    "Accept": "application/json",
    "Authorization": "Bearer "+auth_key
}

#ndustry_epd_url = "https://buildingtransparency.org/api/industry_epds"
product_epd_url = "https://buildingtransparency.org/api/epds"

querystring = {"page_size":"250"}

#indus_response = requests.get(industry_epd_url, headers=headers, params=querystring)
prod_response = requests.get(product_epd_url, headers=headers, params=querystring)

#indus_results = indus_response.json()
prod_results = prod_response.json()

# %%
len(prod_results)
# Out:
# 250

# %%
#total_pages = int(indus_response.headers['X-Total-Pages'])
total_pages2 = int(prod_response.headers['X-Total-Pages'])

#print('Industry EPD Pages: ', total_pages)
print('Product EPD Pages: ', total_pages2)
# Out:
# Product EPD Pages:  722

# %%
product_epds = []

for i in range(0,3):
        querystring = {
                "page_number": i+1,
                "page_size":"250"}
        response = requests.get(product_epd_url, headers=headers, params=querystring)
        epd_data = response.json()
        for epd in epd_data:
                product_epds.append(epd)
        print("successfully completed page "+str(i+1))
# Out:
# successfully completed page 1
# successfully completed page 2
# successfully completed page 3

# %%
product_epds[0]
# Out:
# {'warnings': {'pcr': ['EPD issued after PCR expiry date. Check version or expiry of PCR.'],
#   'impacts': ['EP-FRESH impact not specified',
#    'EP-TERRESTRIAL impact not specified'],
#   'concrete_cement_content': ['Not specified'],
#   'concrete_w_c_ratio': ['Not specified']},
#  'errors': None,
#  'failures': None,
#  'is_failed': False,
#  'confirmable_fields': [],
#  'confirmed_fields': [],
#  'approved_fields': {},
#  'cqd_sync_server_original': None,
#  'cqd_sync_server_from': None,
#  'cqd_sync_id': None,
#  'cqd_sync_updated_on': None,
#  'cqd_sync_unlocked': True,
#  'id': '61d724691af245048a8ad8ccec3f91b7',
#  'created_on': '2020-12-31T14:14:28.609429Z',
#  'updated_on': '2024-07-06T10:12:45Z',
#  'owner': {'user_id': 'cqd.admin@buildingtransparency.org',
#   'name': 'cqd.io Admin'},
#  'my_capabilities': 1,
#  'open_xpd_uuid': 'ec34u6kx',
#  'gwp': '339 kgCO2e',
#  'gwp_z': 0.035020565386641035,
#  'standard_deviation': '11.87197167 kgCO2e',
#  'conservative_estimate': '348.9914514 kgCO2e',
#  'best_practice': '329.0085486 kgCO2e',
#  'uncertainty_factor': 1.0294733078293972,
#  'uncertainty_adjusted_gwp': '348.9914514 kgCO2e',
#  'use_stored_carbon': False,
#  'stored_carbon': None,
#  'stored_carbon_z': 0.2,
#  'biogenic_embodied_carbon': None,
#  'biogenic_embodied_carbon_z': 0.035020565386641035,
#  'language': 'en',
#  'attachments': {'TransparencyCatalogURL': 'https://transparencycatalog.com/company/central-concrete'},
#  'industry_standards': None,
#  'copy_of': None,
#  'mass_per_declared_unit': '2400 kg',
#  'date_of_issue': '2019-01-28',
#  'category': {'id': 'b03dba1dca5b49acb1a5aa4daab546b4',
#   'created_on': '2018-06-26T01:11:48.938840Z',
#   'updated_on': '2024-09-02T14:10:32.118267Z',
#   'name': 'ReadyMix',
#   'display_name': 'Ready Mix',
#   'short_name': 'Ready Mix',
#   'masterformat': '03 30 00 Cast-in-Place Concrete',
#   'unspsc': '30111505',
#   'openepd_name': 'Concrete >> ReadyMix',
#   'openepd': 'Concrete >> ReadyMix',
#   'description': 'Concretes to be mixed and then poured on-site',
#   'declared_unit': '1 m3',
#   'pct10_gwp': '248.5624884 kgCO2e',
#   'pct20_gwp': '284.5893111 kgCO2e',
#   'pct30_gwp': '312.1915057 kgCO2e',
#   'pct40_gwp': '337.2407227 kgCO2e',
#   'pct50_gwp': '362.3040845 kgCO2e',
#   'pct60_gwp': '390.1318439 kgCO2e',
#   'pct70_gwp': '420.316521 kgCO2e',
#   'pct80_gwp': '456.0566754 kgCO2e',
#   'pct90_gwp': '510.9020737 kgCO2e',
#   'mass_per_declared_unit': '2400 kg',
#   'may_contain_trusted_vendor_declarations': False,
#   'beta_only': False,
#   'draft': False,
#   'allows_any_declared_unit': False,
#   'requires_mass_per_declared_unit': False,
#   'category_statistics_warning': False,
#   'no_statistics': False,
#   'short_service_life_disclaimer': False,
#   'hide_service_life': True,
#   'template_builders': [],
#   'generic_material': False,
#   'parents': [],
#   'subcategories': [],
#   'use_stored_carbon': 'ABSENT',
#   'facility_type': 'PLANT',
#   'lcia_uncertainty': 0.03,
#   'includes_b1_stage': False,
#   'massless': False,
#   'obsolete': False,
#   'default_transport_mode': 'concrete mixer truck',
#   'default_distance': '51.49888 km'},
#  'also_shown_in': [],
#  'reviewer': None,
#  'pcr': {'cqd_sync_server_original': None,
#   'cqd_sync_server_from': None,
#   'cqd_sync_id': None,
#   'cqd_sync_updated_on': None,
#   'cqd_sync_unlocked': True,
#   'warnings': None,
#   'errors': None,
#   'failures': None,
#   'is_failed': False,
#   'confirmable_fields': [],
#   'confirmed_fields': [],
#   'id': '64e661dd8d894db3a1bb327f08edae1f',
#   'created_on': '2019-10-07T15:56:48.524245Z',
#   'updated_on': '2023-12-05T00:02:02.009988Z',
#   'owner': None,
#   'my_capabilities': None,
#   'open_xpd_uuid': 'ec37zjz1',
#   'short_link': 'cqd.io/p/ec37zjz1ws',
#   'original_ec3_link': 'https://buildingtransparency.org/ec3/pcrs/ec37zjz1',
#   'name': 'North American PCR for Concrete',
#   'short_name': 'Concrete',
#   'alt_names': ['Product Category Rules (PCR) for ISO 14025:2006 Type III Environmental Product Declarations (EPDs) of Concrete',
#    'North American Product Category Rules (PCR) for ISO 14025 Type III Environmental Product Declarations (EPDs) and/or GHG Protocol Conformant Product â€˜Carbon Footprintâ€™ of Concrete',
#    'North American Product Category Rules v1 (PCR) for ISO 14025 Type III Environmental Product Declarations (EPDs) and/or GHG Protocol Conformant Product â€˜Carbon Footprintâ€™ of Concrete',
#    'Product Category Rules (PCR) for ISO 14025 Type III Environmental Product Declarations (EPDs) Concrete Version 1.1',
#    'CLF PCR for ISO14025 Type III Environmental Product Declarations for Concrete meeting hte requirement of one of the following:  C90, ASTM C90, CSA A23.1/A23.2, UNSPC code 30111500, Version 1.1, Dec 4, 2013 Clarifications 1,2, and 3',
#    'PCR for ISO 14025:2006 Type III EPD of Concrete',
#    'Carbon Leadership Forum (CLF) Product Category Rules (PCR) for ISO 14025 Type III Environmental Product Declarations (EPDs) for Concrete v1.1 (December 2013)',
#    'The Carbon Leadership Forum PCR: PCR for ISO 14025 Type III EPD for Concrete',
#    '""The Carbon Leadership Forum PCR: Product Category Rules (PCR) for ISO 14025 Type III Environmental Product Declarations (EPDs) for Concrete, Version 1.1 dated 12/4/2013, serves as the PCR for this EPD. http://www.carbonleadershipforum.org""'],
#   'issuer_doc_id': None,
#   'date_of_issue': '2013-12-04',
#   'date_validity_ends': '2018-12-04',
#   'version': '1.1',
#   'doc': 'https://app.box.com/file/292552692203',
#   'status': 'Sunset',
#   'attachments': None,
#   'issuer': None,
#   'categories': [],
#   'product_classes': None,
#   'parent': None,
#   'declared_units': ['1 m3'],
#   'requires_mass': False,
#   'requires_uncertainty': False,
#   'allows_facility_specific_epds': None,
#   'lcia_requirements': {'TRACI 2.1': {'order': 1,
#     'jurisdiction': None,
#     'impacts': None}}},
#  'pcr_notes': None,
#  'lca_discussion': '\n\n## Product Component Notes\ncrushed aggregate (ASTM C33), natural aggregate (ASTM C33), Portland cement (ASTM C150), fly ash (ASTM C618), batch water (ASTM C1602), admixture (ASTM C494)\n\n## Source Data Notes\nPortland cement: Portland Concrete Association, Industry Average EPD, 2016 Fly ash: byproduct of coal combustion; no upstream manufacturing impacts Aggregate: Supplier specific primary data, 2018 Aggregate: Supplier specific primary data, 2016 Admixture (waterproofing): EFCA EPD, Europe, 2015 Municipal Water: US-EI (2016): “Tap water, at user/US”, 2000 Truck transport: US-EI (2014): Transport, single unit truck, diesel powered/NREL/US, 2007 and US EPA emission factors, 2014 Rail transport: US-EI (2014): Transport, train, diesel powered NREL/US, 2007 Ship transport: US-EI (2014): Transport, ocean freighter, average fuel mix NREL/US, 2007 Electricity (WECC): Ecoinvent 3.32: “Electricity, medium voltage, market for, Alloc Rec”, 2015 Diesel: US-EI (2016): “Diesel, combusted in industrial equipment/NREL/US”, 2007',
#  'impacts': {},
#  'resource_uses': {},
#  'output_flows': {},
#  'box_id': '751413464508',
#  'doc': 'https://api.climateearth.com/api/mixes/epd/9BD4F9CB-3584-4D34-90F8-B6E40B69653D/true',
#  'date_validity_ends': '2021-10-03',
#  'externally_verified': True,
#  'developer': {'name': 'Laurel McEwen',
#   'email': 'laurel.mcewen@climateearth.com',
#   'org': {'address': '137 Park Place, Richmond, CA 94801',
#    'latitude': 37.9266,
#    'longitude': -122.38494,
#    'location': {'streetNumber': '137',
#     'streetName': 'Park Place',
#     'municipality': 'Richmond',
#     'countrySecondarySubdivision': 'Contra Costa',
#     'countrySubdivision': 'CA',
#     'countrySubdivisionName': 'California',
#     'postalCode': '94801',
#     'extendedPostalCode': '948013895',
#     'countryCode': 'US',
#     'country': 'United States',
#     'countryCodeISO3': 'USA',
#     'freeformAddress': '137 Park Place, Richmond, CA 94801',
#     'localName': 'Richmond'},
#    'address_line': '137 Park Place',
#    'admin_district': 'CA',
#    'admin_district2': 'Contra Costa',
#    'locality': 'Richmond',
#    'postal_code': '94801',
#    'country': 'US',
#    'cqd_sync_server_original': None,
#    'cqd_sync_server_from': None,
#    'cqd_sync_id': None,
#    'cqd_sync_updated_on': None,
#    'cqd_sync_unlocked': True,
#    'warnings': None,
#    'errors': None,
#    'failures': None,
#    'is_failed': False,
#    'confirmable_fields': [],
#    'confirmed_fields': [],
#    'id': '5d43c53212c848d9861a81a4bbd626b2',
#    'created_on': '2018-09-07T12:26:19.155179Z',
#    'updated_on': '2023-10-06T13:31:13.719486Z',
#    'owner': None,
#    'my_capabilities': None,
#    'name': 'Climate Earth',
#    'image': 'https://cqddatastore.blob.core.windows.net/cqd/images/7ce922a6-8120-420c-9ca9-cd4ff793d90e',
#    'horizontal_logo': None,
#    'legal_name': 'Climate Earth',
#    'alt_names': ['Climate Earth, Inc.',
#     'Climate Earth',
#     'carbonCLARITY Suite'],
#    'email_extensions': ['climateearth.com'],
#    'parent_email_extensions': None,
#    'attachments': None,
#    'jurisdiction': None,
#    'password_login_allowed': True,
#    'po_geography': None,
#    'primary_lcia_method': None,
#    'primary_activity_owner': False,
#    'primary_activity_builder': False,
#    'primary_activity_general_contractor': False,
#    'primary_activity_subcontractor': False,
#    'primary_activity_design': False,
#    'primary_activity_manufacturer': False,
#    'primary_activity_operator': False,
#    'primary_activity_verifier': True,
#    'primary_activity_industry_association': False,
#    'primary_activity_epd_developer': False,
#    'primary_activity_other': False,
#    'primary_activity_forest_practices_certification': False,
#    'primary_activity_digitization_qa': False,
#    'primary_activity_sustainability_consulting': True,
#    'primary_activity_performance_standards_issuer': False,
#    'primary_activity_education': False,
#    'primary_activity_pcr_publisher': False,
#    'primary_activity_government': False,
#    'iso9001_certified': None,
#    'iso14001_certified': None,
#    'tax_id': None,
#    'website': 'https://climateearth.com/',
#    'web_domain': 'climateearth.com',
#    'email': None,
#    'invalid_after': None,
#    'org_type': 'Private',
#    'currency': None,
#    'enterprise': True,
#    'pilot_all_employees': False,
#    'parent': None,
#    'gwp_contact': None,
#    'user_group_employees': None,
#    'user_group_collaborators': None,
#    'core_pcrs': None,
#    'general_program_instructions': None,
#    'original_ec3_link': 'https://buildingtransparency.org/ec3/organizations/5d43c53212c848d9861a81a4bbd626b2'}},
#  'verifier': {'name': 'Rita Schenck',
#   'email': 'rita@iere.org',
#   'org': {'address': '10857 98th Place Southwest, Vashon, WA 98070',
#    'latitude': 47.447029,
#    'longitude': -122.459793,
#    'location': {'buildingNumber': '10857',
#     'streetNumber': '10857',
#     'routeNumbers': [],
#     'street': '98th Place Southwest',
#     'streetName': '98th Place Southwest',
#     'streetNameAndNumber': '10857 98th Place Southwest',
#     'countryCode': 'US',
#     'countrySubdivision': 'WA',
#     'countrySecondarySubdivision': 'King',
#     'countryTertiarySubdivision': 'Vashon Island',
#     'municipality': 'Vashon',
#     'postalCode': '98070',
#     'municipalitySubdivision': 'Vashon',
#     'country': 'United States',
#     'countryCodeISO3': 'USA',
#     'freeformAddress': '10857 98th Place Southwest, Vashon, WA 98070',
#     'boundingBox': {'northEast': '47.447447,-122.459782',
#      'southWest': '47.446493,-122.459807',
#      'entity': 'position'},
#     'countrySubdivisionName': 'Washington'},
#    'address_line': '10857 98th Place Southwest',
#    'admin_district': 'WA',
#    'admin_district2': 'King',
#    'locality': 'Vashon',
#    'postal_code': '98070',
#    'country': 'US',
#    'cqd_sync_server_original': None,
#    'cqd_sync_server_from': None,
#    'cqd_sync_id': None,
#    'cqd_sync_updated_on': None,
#    'cqd_sync_unlocked': True,
#    'warnings': None,
#    'errors': None,
#    'failures': None,
#    'is_failed': False,
#    'confirmable_fields': [],
#    'confirmed_fields': [],
#    'id': '5609a6ef730f45d381c0dfcc8f1e4030',
#    'created_on': '2018-07-26T13:26:41.418139Z',
#    'updated_on': '2024-07-24T16:50:05.976251Z',
#    'owner': None,
#    'my_capabilities': None,
#    'name': 'EarthSure',
#    'image': 'https://cqddatastore.blob.core.windows.net/cqd/images/09578c87-ff1e-4bef-b9de-710d039dda6c.png',
#    'horizontal_logo': None,
#    'legal_name': 'EarthSure',
#    'alt_names': ['Earthsure',
#     'IERE',
#     'Institute for Environmental Research and Education'],
#    'email_extensions': ['iere.org'],
#    'parent_email_extensions': None,
#    'attachments': None,
#    'jurisdiction': None,
#    'password_login_allowed': True,
#    'po_geography': ['US'],
#    'primary_lcia_method': None,
#    'primary_activity_owner': False,
#    'primary_activity_builder': False,
#    'primary_activity_general_contractor': False,
#    'primary_activity_subcontractor': False,
#    'primary_activity_design': False,
#    'primary_activity_manufacturer': False,
#    'primary_activity_operator': True,
#    'primary_activity_verifier': True,
#    'primary_activity_industry_association': False,
#    'primary_activity_epd_developer': False,
#    'primary_activity_other': False,
#    'primary_activity_forest_practices_certification': False,
#    'primary_activity_digitization_qa': False,
#    'primary_activity_sustainability_consulting': False,
#    'primary_activity_performance_standards_issuer': False,
#    'primary_activity_education': False,
#    'primary_activity_pcr_publisher': False,
#    'primary_activity_government': False,
#    'iso9001_certified': None,
#    'iso14001_certified': None,
#    'tax_id': None,
#    'website': 'http://iere.org/programs/earthsure/',
#    'web_domain': 'iere.org',
#    'email': None,
#    'invalid_after': '2018-07-01',
#    'org_type': 'Private',
#    'currency': None,
#    'enterprise': True,
#    'pilot_all_employees': False,
#    'parent': None,
#    'gwp_contact': None,
#    'user_group_employees': None,
#    'user_group_collaborators': None,
#    'core_pcrs': None,
#    'general_program_instructions': None,
#    'original_ec3_link': 'https://buildingtransparency.org/ec3/organizations/5609a6ef730f45d381c0dfcc8f1e4030'}},
#  'program_operator': {'address': '100 Barr Harbor Dr, Conshohocken, PA 19428, USA',
#   'latitude': 40.0689574,
#   'longitude': -75.3083283,
#   'location': [{'long_name': '100',
#     'short_name': '100',
#     'types': ['street_number']},
#    {'long_name': 'Barr Harbor Drive',
#     'short_name': 'Barr Harbor Dr',
#     'types': ['route']},
#    {'long_name': 'Conshohocken',
#     'short_name': 'Conshohocken',
#     'types': ['locality', 'political']},
#    {'long_name': 'Montgomery County',
#     'short_name': 'Montgomery County',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'Pennsylvania',
#     'short_name': 'PA',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']},
#    {'long_name': '19428', 'short_name': '19428', 'types': ['postal_code']},
#    {'long_name': '2951',
#     'short_name': '2951',
#     'types': ['postal_code_suffix']}],
#   'address_line': '100 Barr Harbor Dr',
#   'admin_district': 'PA',
#   'admin_district2': 'Montgomery County',
#   'locality': 'Conshohocken',
#   'postal_code': '19428',
#   'country': 'US',
#   'cqd_sync_server_original': None,
#   'cqd_sync_server_from': None,
#   'cqd_sync_id': None,
#   'cqd_sync_updated_on': None,
#   'cqd_sync_unlocked': True,
#   'warnings': None,
#   'errors': None,
#   'failures': None,
#   'is_failed': False,
#   'confirmable_fields': [],
#   'confirmed_fields': [],
#   'id': '2657c6a84bfa4675a5e4ee785c253a48',
#   'created_on': '2018-10-01T05:13:50.328641Z',
#   'updated_on': '2024-07-22T20:35:58.976247Z',
#   'owner': None,
#   'my_capabilities': None,
#   'name': 'ASTM International',
#   'image': 'https://cqddatastore.blob.core.windows.net/cqd/images/d2e41902-21b7-486d-b303-d84c4b95ecfc.png',
#   'horizontal_logo': None,
#   'legal_name': 'ASTM International',
#   'alt_names': ['astm', 'ASTMInternational'],
#   'email_extensions': ['astm.org'],
#   'parent_email_extensions': None,
#   'attachments': {'Programme Instructions': 'https://www.astm.org/CERTIFICATION/DOCS/162.ASTM_General_Program_Instructions_6.0_110414.pdf'},
#   'jurisdiction': None,
#   'password_login_allowed': True,
#   'po_geography': ['US', 'CA'],
#   'primary_lcia_method': None,
#   'primary_activity_owner': False,
#   'primary_activity_builder': False,
#   'primary_activity_general_contractor': False,
#   'primary_activity_subcontractor': False,
#   'primary_activity_design': False,
#   'primary_activity_manufacturer': False,
#   'primary_activity_operator': True,
#   'primary_activity_verifier': True,
#   'primary_activity_industry_association': False,
#   'primary_activity_epd_developer': False,
#   'primary_activity_other': True,
#   'primary_activity_forest_practices_certification': False,
#   'primary_activity_digitization_qa': False,
#   'primary_activity_sustainability_consulting': False,
#   'primary_activity_performance_standards_issuer': True,
#   'primary_activity_education': False,
#   'primary_activity_pcr_publisher': False,
#   'primary_activity_government': False,
#   'iso9001_certified': None,
#   'iso14001_certified': None,
#   'tax_id': None,
#   'website': 'https://www.astm.org/CERTIFICATION/EpdAndPCRs.html',
#   'web_domain': 'astm.org',
#   'email': None,
#   'invalid_after': None,
#   'org_type': 'Private',
#   'currency': None,
#   'enterprise': True,
#   'pilot_all_employees': False,
#   'parent': None,
#   'gwp_contact': None,
#   'user_group_employees': None,
#   'user_group_collaborators': None,
#   'core_pcrs': None,
#   'general_program_instructions': None,
#   'original_ec3_link': 'https://buildingtransparency.org/ec3/organizations/2657c6a84bfa4675a5e4ee785c253a48'},
#  'program_operator_fkey': '9BD4F9CB-3584-4D34-90F8-B6E40B69653D',
#  'document_version': '1',
#  'third_party_verification_url': None,
#  'digitization_qa': None,
#  'digitization_qa_notes': None,
#  'digitization_confirmed_on': None,
#  'digitization_confirmed': None,
#  'original_data_format': 'custom_api',
#  'product_specific': True,
#  'is_downloadable': True,
#  'sanitizable': True,
#  'epd_degraded': False,
#  'excluded': False,
#  'not_an_epd': False,
#  'requires_ocr': False,
#  'is_duplicate': False,
#  'multiproduct': False,
#  'are_impacts_locked': False,
#  'product_usage_description': None,
#  'product_usage_image': None,
#  'product_usage_image_crop_area': None,
#  'manufacturing_description': None,
#  'manufacturing_image': None,
#  'manufacturing_image_crop_area': None,
#  'asphalt_aggregate_size_max': None,
#  'asphalt_rap': None,
#  'asphalt_ras': None,
#  'asphalt_ground_tire_rubber': None,
#  'asphalt_max_temperature': None,
#  'asphalt_min_temperature': None,
#  'asphalt_mix_type': None,
#  'asphalt_gradation': None,
#  'asphalt_sbr': None,
#  'asphalt_sbs': None,
#  'asphalt_ppa': None,
#  'asphalt_gtr': None,
#  'asphalt_pmb': None,
#  'steel_yield_tensile_str': None,
#  'steel_bar_elongation': None,
#  'steel_recycled_content': None,
#  'steel_post_consumer_recycled_content': None,
#  'steel_astm_marking': None,
#  'steel_euro_marking': None,
#  'steel_rebar_diameter_min': None,
#  'steel_rebar_bending_pin_max': None,
#  'steel_rebar_ts_ys_ratio_max': None,
#  'steel_rebar_grade': None,
#  'steel_modulus_of_elasticity': None,
#  'steel_thermal_expansion': None,
#  'steel_thermal_conductivity': None,
#  'steel_composition': None,
#  'astm_standards': None,
#  'sae_standards': None,
#  'en_standards': None,
#  'cold_finished': None,
#  'galvanized': None,
#  'stainless': None,
#  'epoxy_coated': None,
#  'steel_fabricated': None,
#  'steel_making_route_bof': None,
#  'steel_making_route_eaf': None,
#  'steel_making_route_ohf': None,
#  'wall_base_material': None,
#  'decking_board_material': None,
#  'astm_type': None,
#  'c1157': None,
#  'cement_scm': None,
#  'csa_a3001': None,
#  'en197_1': None,
#  'oil_well_cement': None,
#  'access_flooring_core_material': None,
#  'access_flooring_finish_material': None,
#  'access_flooring_stringers': None,
#  'access_flooring_seismic_rating': None,
#  'access_flooring_magnetically_attached_finish': None,
#  'access_flooring_permanent_finish': None,
#  'access_flooring_drylay': None,
#  'access_flooring_adjustable_height': None,
#  'access_flooring_fixed_height': None,
#  'access_flooring_finished_floor_height': None,
#  'access_flooring_panel_thickness': None,
#  'access_flooring_concentrated_load': None,
#  'access_flooring_uniform_load': None,
#  'access_flooring_rolling_load_10_pass': None,
#  'access_flooring_rolling_load_10000_pass': None,
#  'textiles_fabric_type': None,
#  'roof_cover_boards_material': None,
#  'roof_cover_boards_thickness': None,
#  'roof_cover_boards_facing': None,
#  'siding_insulated': None,
#  'siding_ventilated': None,
#  'siding_paint_or_stain_required': None,
#  'siding_r_value': None,
#  'siding_form_factor': None,
#  'masonry_cement_astm_c91_type': None,
#  'vinyl_siding_thickness': None,
#  'nafs_performance_class_r': None,
#  'nafs_performance_class_lc': None,
#  'nafs_performance_class_cw': None,
#  'nafs_performance_class_aw': None,
#  'glazing_intended_application_curtain_wall': None,
#  'glazing_intended_application_r_windows': None,
#  'glazing_intended_application_lc_windows': None,
#  'glazing_intended_application_cw_windows': None,
#  'glazing_intended_application_aw_windows': None,
#  'glazing_intended_application_storefronts': None,
#  'glazing_intended_application_glazed_doors': None,
#  'glazing_intended_application_unit_skylights': None,
#  'glazing_intended_application_sloped_skylights': None,
#  'glazing_intended_application_other': None,
#  'acid_etched': None,
#  'electrochromic': None,
#  'fire_resistant': None,
#  'laminated': None,
#  'low_emissivity': None,
#  'pyrolytic_coated': None,
#  'sputter_coat': None,
#  'tempered': None,
#  'toughened': None,
#  'hurricane_resistant': None,
#  'fire_protection': None,
#  'nafs_performance_grade': None,
#  'glass_panes': None,
#  'dp_rating': None,
#  'air_infiltration': None,
#  'solar_heat_gain': None,
#  'flat_glass_panes_thickness': None,
#  'assembly_u_factor': None,
#  'cog_u_factor': None,
#  'thermal_separation': None,
#  'spacer': None,
#  'frame_material': None,
#  'hardware_function': None,
#  'energy_source': None,
#  'cabling_category': None,
#  'fire_rating': None,
#  'jacket_material': None,
#  'shielded': None,
#  'armored': None,
#  'rohs': None,
#  'reach': None,
#  'zwtl': None,
#  'connectorized': None,
#  'thin_ethernet': None,
#  'amperage': None,
#  'outlet_level_metering': None,
#  'outlet_level_switching': None,
#  'pdu_technology': None,
#  'pdu_outlets': None,
#  'ventilated': None,
#  'depth': None,
#  'cable_trays_material': None,
#  'divided': None,
#  'raceways_material': None,
#  'fire_classified': None,
#  'raised': None,
#  'poke_through': None,
#  'floor_box_cover': None,
#  'painted': None,
#  'floor_box_outlets': None,
#  'floor_box_material': None,
#  'floor_box_cover_material': None,
#  'floor_box_floor_material': None,
#  'total_racking_units': None,
#  'static_load': None,
#  'rack_type': None,
#  'conduit_nominal_diameter': None,
#  'conduit_outer_diameter': None,
#  'conduit_inner_diameter': None,
#  'conduit_wall_thickness': None,
#  'conduit_material': None,
#  'elevators_travel_length': None,
#  'elevators_rated_load': None,
#  'elevators_rated_speed': None,
#  'elevators_building_rise': None,
#  'elevators_usage_intensity': None,
#  'flooring': None,
#  'wall_finish': None,
#  'cladding': None,
#  'other': None,
#  'residential_only': None,
#  'reinforced': None,
#  'thickness': None,
#  'tiling_total_recycled_content': None,
#  'tiling_post_consumer_recycled_content': None,
#  'regular': None,
#  'glass_mosaic': None,
#  'miniature_mosaic': None,
#  'large_format': None,
#  'tile_panels': None,
#  'tile_pavers': None,
#  'porcelain': None,
#  'quarry': None,
#  'pressed_floor_tile': None,
#  'wall_tile': None,
#  'mosaic_tile': None,
#  'specialty': None,
#  'countertop_material': None,
#  'air_volume': None,
#  'airflow_rate': None,
#  'cooling_capacity': None,
#  'heating_capacity': None,
#  'mechanical_installation': None,
#  'ahu_airflow_control': None,
#  'ahu_zone_control': None,
#  'mechanical_refrigerants': None,
#  'pump_discharge_pressure': None,
#  'pump_horsepower': None,
#  'heat_pumps_type': None,
#  'boilers_configuration': None,
#  'boilers_equipment_fuel_type': None,
#  'flow_rate': None,
#  'air_filters_merv_rating': None,
#  'air_filters_media_type': None,
#  'hvac_heat_exchangers_type': None,
#  'hvac_ducts_type': None,
#  'hvac_ducts_shape': None,
#  'hvac_ducts_material': None,
#  'cmu_weight_classification': None,
#  'cmu_block_type': None,
#  'cmu_insulated': None,
#  'cmu_sound_performance': None,
#  'concrete_compressive_strength_28d': '20.7 MPa',
#  'concrete_compressive_strength_other': None,
#  'concrete_compressive_strength_other_d': None,
#  'concrete_flexion_strength': None,
#  'concrete_slump': '4 in',
#  'concrete_min_slump': '3 in',
#  'concrete_max_slump': '5 in',
#  'concrete_w_c_ratio': None,
#  'concrete_aggregate_size_max': '0.75 in',
#  'concrete_min_pipeline_size': '3 in',
#  'cementitious': {'opc': None,
#   'wht': None,
#   'ggbs': None,
#   'fly_ash': 0.15,
#   'si_fume': None,
#   'nat_poz': None,
#   'gg45': None,
#   'mk': None,
#   'CaCO3': None,
#   'other': None},
#  'concrete_air_entrain': True,
#  'concrete_co2_entrain': False,
#  'concrete_self_consolidating': False,
#  'white_cement': False,
#  'plc': False,
#  'lightweight': False,
#  'fiber_reinforced': None,
#  'fnd': None,
#  'sog': None,
#  'hrz': None,
#  'vrt_wall': None,
#  'vrt_column': None,
#  'vrt_other': None,
#  'sht': None,
#  'cdf': None,
#  'sac': None,
#  'pav': None,
#  'oil': None,
#  'grt': None,
#  'ota': None,
#  'aci_exposure_classes': None,
#  'csa_exposure_classes': None,
#  'en_exposure_classes': None,
#  'brick_building': None,
#  'brick_facing': None,
#  'brick_floor': None,
#  'brick_pedestrian': None,
#  'brick_paving': None,
#  'brick_other': None,
#  'brick_chemical_resistant': None,
#  'brick_glazed': None,
#  'brick_tiles': None,
#  'spray_fireproofing_material_type': None,
#  'spray_fireproofing_density': None,
#  'intumescent_fireproofing_material_type': None,
#  'insulated': None,
#  'gfrc': None,
#  'steel_mass_percentage': None,
#  'precast_element_type_wall': None,
#  'precast_element_type_solid_slab': None,
#  'precast_element_type_hollowcore': None,
#  'precast_element_type_beam': None,
#  'precast_element_type_column': None,
#  'precast_element_type_stairs': None,
#  'precast_element_type_balcony': None,
#  'precast_element_type_pile': None,
#  'precast_element_type_manhole': None,
#  'precast_element_type_retaining_wall': None,
#  'precast_element_type_box_culvert': None,
#  'precast_element_type_road_barriers': None,
#  'precast_element_type_rail_sleeper': None,
#  'buried_piping_type': None,
#  'mass_per_unit_length': None,
#  'piping_diameter': None,
#  'piping_ansi_schedule': None,
#  'fire_protection_piping_material': None,
#  'plumbing_piping_material': None,
#  'utility_piping_material': None,
#  'dimmable': None,
#  'color_temperature': None,
#  'typical_utilization': None,
#  'luminosity': None,
#  'wattage': None,
#  'color_rendering_index': None,
#  'recycled_aggregate': None,
#  'aggregate_nominal_max_size': None,
#  'aggregate_weight_classification': None,
#  'aggregate_gradation': None,
#  'manufactured': None,
#  'slag': None,
#  'concrete': None,
#  'asphalt': None,
#  'unbound': None,
#  'speed': None,
#  'vertical_rise': None,
#  'step_width': None,
#  'max_capacity': None,
#  'application_rate': None,
#  'plaster_composition': None,
#  'name': 'DM0115CA',
#  'alt_names': None,
#  'description': 'DOT MINOR 3/4" 15FA 3-5SL AIR',
#  'sku': None,
#  'image': 'https://cqddatastore.blob.core.windows.net/cqd/images/dcef172d48e947a6a7f415aded1f7691.png',
#  'image_small': None,
#  'applicable_in': ['001'],
#  'product_classes': None,
#  'density': '2400 kg / m^3',
#  'gypsum_fire_rating': None,
#  'gypsum_thickness': None,
#  'specific_density': None,
#  'gypsum_specific_density': None,
#  'gypsum_r_factor': None,
#  'gypsum_flame_spread_astm_e84': None,
#  'gypsum_smoke_production_astm_e84': None,
#  'gypsum_surface_abrasion_d4977': None,
#  'gypsum_indentation_d5420': None,
#  'gypsum_soft_body_impact_e695': None,
#  'gypsum_hard_body_impact_c1929': None,
#  'gypsum_facing': None,
#  'mold_resistant': None,
#  'foil_backing': None,
#  'moisture_resistant': None,
#  'abuse_resistant': None,
#  'timber_species': None,
#  'fabrication': None,
#  'weather_exposed': None,
#  'fire_retardant': None,
#  'decay_resistant': None,
#  'wood_board_thickness': None,
#  'reference_service_life': None,
#  'intended_application': None,
#  'insulation_intended_application': None,
#  'manufacture_type': None,
#  'form_factor': None,
#  'yarn_weight': None,
#  'yarn_type': None,
#  'fire_radiant_panel_rating_astme648': None,
#  'fire_smoke_density_rating_astme648': None,
#  'voc_emissions': None,
#  'insulating_material': None,
#  'thickness_per_declared_unit': None,
#  'foam_type': None,
#  'cushioned': None,
#  'bleachable': None,
#  'width': None,
#  'height': None,
#  'length': None,
#  'indoor': None,
#  'outdoor': None,
#  'recycled_content': None,
#  'cladding_r_value': None,
#  'cladding_insulating_material': None,
#  'cladding_facing_material': None,
#  'features': None,
#  'forest_practices_certifiers': None,
#  'ceiling_panel_core_material': None,
#  'ceiling_panel_nrc': None,
#  'ceiling_panel_cac': None,
#  'resilient_flooring_wear_layer': None,
#  'resilient_flooring_form_factor': None,
#  'resilient_flooring_material': None,
#  'resilient_flooring_delta_iic': None,
#  'resilient_flooring_thickness': None,
#  'sport_flooring': None,
#  'conductive_flooring': None,
#  'floor_score': None,
#  'nsf332': None,
#  'sheet_construction': None,
#  'sri': None,
#  'total_recycled_content': None,
#  'post_consumer_recycled_content': None,
#  'membrane_roofing_reinforcement': None,
#  'felt_backing': None,
#  'nsf347': None,
#  'vantage_vinyl': None,
#  'compressive_strength': None,
#  'admixture_effects': None,
#  'alloy': None,
#  'anodized': None,
#  'thermally_improved': None,
#  'cement_board_thickness': None,
#  'aac_thermal_conductivity': None,
#  'aac_white': None,
#  'declaration_type': 'Product EPD',
#  'short_link': 'cqd.io/e/ec34u6kxd6',
#  'original_ec3_link': 'https://buildingtransparency.org/ec3/epds/ec34u6kx',
#  'material_id': '91f7d01b7b5540509e42315637c0cc01',
#  'file_name': 'Central Concrete_004W_DM0115CA_9BD4F9CB-3584-4D34-90F8-B6E40B69653D_1.pdf',
#  'declared_unit': '1 m3',
#  'gwp_per_category_declared_unit': '339 kgCO2e',
#  'pct80_gwp_per_category_declared_unit': '348.9914514 kgCO2e',
#  'gwp_per_kg': '0.14125 kgCO2e',
#  'lowest_plausible_gwp': '329.0085486 kgCO2e',
#  'jurisdiction': ['001'],
#  'plant_geography': ['US-CA'],
#  'matched_plants_count': 0,
#  'manufacturer': {'address': '755 Stockton Avenue, San Jose, CA 95126',
#   'latitude': 37.34156,
#   'longitude': -121.91509,
#   'location': {'streetNumber': '755',
#    'streetName': 'Stockton Avenue',
#    'municipalitySubdivision': 'San Jose, College Park',
#    'municipality': 'San Jose',
#    'countrySecondarySubdivision': 'Santa Clara',
#    'countryTertiarySubdivision': 'San Jose',
#    'countrySubdivision': 'CA',
#    'postalCode': '95126',
#    'countryCode': 'US',
#    'country': 'United States Of America',
#    'countryCodeISO3': 'USA',
#    'freeformAddress': '755 Stockton Avenue, San Jose, CA 95126',
#    'countrySubdivisionName': 'California'},
#   'address_line': '755 Stockton Avenue',
#   'admin_district': 'CA',
#   'admin_district2': 'Santa Clara',
#   'locality': 'San Jose',
#   'postal_code': '95126',
#   'country': 'US',
#   'cqd_sync_server_original': None,
#   'cqd_sync_server_from': None,
#   'cqd_sync_id': None,
#   'cqd_sync_updated_on': None,
#   'cqd_sync_unlocked': True,
#   'warnings': None,
#   'errors': None,
#   'failures': None,
#   'is_failed': False,
#   'confirmable_fields': [],
#   'confirmed_fields': [],
#   'id': 'c3d7d8d1e466457798d8c37c0df44cee',
#   'created_on': '2018-06-21T14:55:59.965541Z',
#   'updated_on': '2024-06-21T18:31:05.255783Z',
#   'owner': None,
#   'my_capabilities': None,
#   'name': 'Central Concrete',
#   'image': 'https://cqddatastore.blob.core.windows.net/cqd/images/baee2a14-dfb9-4e9a-b1b7-f14134e3689b.png',
#   'horizontal_logo': None,
#   'legal_name': 'CENTRAL CONCRETE Supply Company',
#   'alt_names': ['Central Concrete', 'Monumental Concrete', 'Centre Concrete'],
#   'email_extensions': ['centralconcrete.com'],
#   'parent_email_extensions': None,
#   'attachments': {'TransparencyCatalogURL': 'https://transparencycatalog.com/company/central-concrete'},
#   'jurisdiction': None,
#   'password_login_allowed': True,
#   'po_geography': None,
#   'primary_lcia_method': None,
#   'primary_activity_owner': False,
#   'primary_activity_builder': False,
#   'primary_activity_general_contractor': False,
#   'primary_activity_subcontractor': False,
#   'primary_activity_design': False,
#   'primary_activity_manufacturer': True,
#   'primary_activity_operator': False,
#   'primary_activity_verifier': False,
#   'primary_activity_industry_association': False,
#   'primary_activity_epd_developer': False,
#   'primary_activity_other': False,
#   'primary_activity_forest_practices_certification': False,
#   'primary_activity_digitization_qa': False,
#   'primary_activity_sustainability_consulting': False,
#   'primary_activity_performance_standards_issuer': False,
#   'primary_activity_education': False,
#   'primary_activity_pcr_publisher': False,
#   'primary_activity_government': False,
#   'iso9001_certified': None,
#   'iso14001_certified': None,
#   'tax_id': None,
#   'website': 'http://www.centralconcrete.com/',
#   'web_domain': 'centralconcrete.com',
#   'email': None,
#   'invalid_after': None,
#   'org_type': 'Private',
#   'currency': None,
#   'enterprise': True,
#   'pilot_all_employees': False,
#   'parent': None,
#   'gwp_contact': None,
#   'user_group_employees': None,
#   'user_group_collaborators': None,
#   'core_pcrs': None,
#   'general_program_instructions': None,
#   'original_ec3_link': 'https://buildingtransparency.org/ec3/organizations/c3d7d8d1e466457798d8c37c0df44cee'},
#  'plant_or_group': {'cqd_sync_server_original': None,
#   'cqd_sync_server_from': None,
#   'cqd_sync_id': None,
#   'cqd_sync_updated_on': None,
#   'cqd_sync_unlocked': True,
#   'warnings': None,
#   'errors': None,
#   'failures': None,
#   'is_failed': False,
#   'confirmable_fields': [],
#   'confirmed_fields': [],
#   'id': '94d64e40a39a4aea85dbb4cb571eae7a',
#   'created_on': '2024-02-20T22:43:56.611033Z',
#   'updated_on': '2024-08-23T19:04:49.729021Z',
#   'owner': None,
#   'my_capabilities': None,
#   'name': 'Queens Lane (wet)',
#   'alt_names': None,
#   'owned_by': {'address': '755 Stockton Avenue, San Jose, CA 95126',
#    'latitude': 37.34156,
#    'longitude': -121.91509,
#    'location': {'streetNumber': '755',
#     'streetName': 'Stockton Avenue',
#     'municipalitySubdivision': 'San Jose, College Park',
#     'municipality': 'San Jose',
#     'countrySecondarySubdivision': 'Santa Clara',
#     'countryTertiarySubdivision': 'San Jose',
#     'countrySubdivision': 'CA',
#     'postalCode': '95126',
#     'countryCode': 'US',
#     'country': 'United States Of America',
#     'countryCodeISO3': 'USA',
#     'freeformAddress': '755 Stockton Avenue, San Jose, CA 95126',
#     'countrySubdivisionName': 'California'},
#    'address_line': '755 Stockton Avenue',
#    'admin_district': 'CA',
#    'admin_district2': 'Santa Clara',
#    'locality': 'San Jose',
#    'postal_code': '95126',
#    'country': 'US',
#    'cqd_sync_server_original': None,
#    'cqd_sync_server_from': None,
#    'cqd_sync_id': None,
#    'cqd_sync_updated_on': None,
#    'cqd_sync_unlocked': True,
#    'warnings': None,
#    'errors': None,
#    'failures': None,
#    'is_failed': False,
#    'confirmable_fields': [],
#    'confirmed_fields': [],
#    'id': 'c3d7d8d1e466457798d8c37c0df44cee',
#    'created_on': '2018-06-21T14:55:59.965541Z',
#    'updated_on': '2024-06-21T18:31:05.255783Z',
#    'owner': None,
#    'my_capabilities': None,
#    'name': 'Central Concrete',
#    'image': 'https://cqddatastore.blob.core.windows.net/cqd/images/baee2a14-dfb9-4e9a-b1b7-f14134e3689b.png',
#    'horizontal_logo': None,
#    'legal_name': 'CENTRAL CONCRETE Supply Company',
#    'alt_names': ['Central Concrete', 'Monumental Concrete', 'Centre Concrete'],
#    'email_extensions': ['centralconcrete.com'],
#    'parent_email_extensions': None,
#    'attachments': {'TransparencyCatalogURL': 'https://transparencycatalog.com/company/central-concrete'},
#    'jurisdiction': None,
#    'password_login_allowed': True,
#    'po_geography': None,
#    'primary_lcia_method': None,
#    'primary_activity_owner': False,
#    'primary_activity_builder': False,
#    'primary_activity_general_contractor': False,
#    'primary_activity_subcontractor': False,
#    'primary_activity_design': False,
#    'primary_activity_manufacturer': True,
#    'primary_activity_operator': False,
#    'primary_activity_verifier': False,
#    'primary_activity_industry_association': False,
#    'primary_activity_epd_developer': False,
#    'primary_activity_other': False,
#    'primary_activity_forest_practices_certification': False,
#    'primary_activity_digitization_qa': False,
#    'primary_activity_sustainability_consulting': False,
#    'primary_activity_performance_standards_issuer': False,
#    'primary_activity_education': False,
#    'primary_activity_pcr_publisher': False,
#    'primary_activity_government': False,
#    'iso9001_certified': None,
#    'iso14001_certified': None,
#    'tax_id': None,
#    'website': 'http://www.centralconcrete.com/',
#    'web_domain': 'centralconcrete.com',
#    'email': None,
#    'invalid_after': None,
#    'org_type': 'Private',
#    'currency': None,
#    'enterprise': True,
#    'pilot_all_employees': False,
#    'parent': None,
#    'gwp_contact': None,
#    'user_group_employees': None,
#    'user_group_collaborators': None,
#    'core_pcrs': None,
#    'general_program_instructions': None,
#    'original_ec3_link': 'https://buildingtransparency.org/ec3/organizations/c3d7d8d1e466457798d8c37c0df44cee'},
#   'notes': None,
#   'categories': [],
#   'total_epds': 2867,
#   'distance': None,
#   'address': '457 Queens Ln, San Jose, CA 95112, USA',
#   'latitude': 37.3704404,
#   'longitude': -121.9033737,
#   'location': [{'long_name': '457',
#     'short_name': '457',
#     'types': ['street_number']},
#    {'long_name': 'Queens Lane', 'short_name': 'Queens Ln', 'types': ['route']},
#    {'long_name': 'North San Jose',
#     'short_name': 'North San Jose',
#     'types': ['neighborhood', 'political']},
#    {'long_name': 'San Jose',
#     'short_name': 'San Jose',
#     'types': ['locality', 'political']},
#    {'long_name': 'Santa Clara County',
#     'short_name': 'Santa Clara County',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'California',
#     'short_name': 'CA',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']},
#    {'long_name': '95112', 'short_name': '95112', 'types': ['postal_code']},
#    {'long_name': '4310',
#     'short_name': '4310',
#     'types': ['postal_code_suffix']}],
#   'address_line': '457 Queens Ln',
#   'admin_district': 'CA',
#   'admin_district2': 'Santa Clara County',
#   'locality': 'San Jose',
#   'postal_code': '95112',
#   'country': 'US',
#   'openepd_id': '849W93CW+5M.centralconcrete.com',
#   'attachments': None,
#   'currency': None,
#   'units': None,
#   'invalid_after': None,
#   'origin_code': None,
#   'carbon_intensity': '498.686 lbCO2e / MWh',
#   'type': 'Plant'},
#  'manufacturer_specific': True,
#  'third_party_verified': True,
#  'plant_specific': True,
#  'private': False,
#  'supply_chain_specific': 0.85,
#  'includes': None,
#  'my_material_capabilities': None,
#  'corrections_count': 0}

# %%
for x in range(1001):  # Example loop running from 0 to 999
    if x % 250 == 0:
        # Your code here
        print(f"{x} is an interval of 250")
# Out:
# 0 is an interval of 250
# 250 is an interval of 250
# 500 is an interval of 250
# 750 is an interval of 250
# 1000 is an interval of 250

# %%
from datetime import datetime
import requests
#category = ['GWP-total','GWP-biogenic','GWP-fossil','GWP-IOBC']

headers = {
    "Accept": "application/json",
    "Authorization": "Bearer "+auth_key
}

product_epd_url = "https://buildingtransparency.org/api/epds"
impact_info_url = "https://openepd.buildingtransparency.org/api/epds/"

EPDs = []
EC3_epds = []
product_epds = []
none = "Unmapped"
i = 0

for x in range(0,10):
    if x % 250 == 0:
        querystring = {
                "page_number": i+1,
                "page_size":"250"}
        response = requests.get(product_epd_url, headers=headers, params=querystring)
        epd_data = response.json()
        for epd in epd_data:
                product_epds.append(epd)
        print("successfully completed page "+str(i+1))


    #date_validity_ends_str = EC3_epds[x]['date_validity_ends']
    #date_validity_ends = datetime.strptime(date_validity_ends_str, '%Y-%m-%d')

    #if date_validity_ends < datetime.now():
        #print(f"EPD {x} expired, skipping...")
        #continue
'''
    xpdID = EC3_epds[x]['open_xpd_uuid']
    response_impact = requests.get(impact_info_url+xpdID, headers=headers)
    impact = response_impact.json()


    ############################### DATA PATHS #################################
    EPDname = EC3_epds[x]['category']['display_name']
    desc = EC3_epds[x]['category']['description']
    seLi = EC3_epds[x]['reference_service_life']
    pcr_name = EC3_epds[x]['pcr']['name']
    pcr_id = EC3_epds[x]['pcr']['id']
    short_link = EC3_epds[x]['pcr']['short_link']

    thckqty = EC3_epds[x]['thickness']
    thckU = EC3_epds[x]['thickness_per_declared_unit']

    tMode = EC3_epds[x]['category']['default_transport_mode']
    dist = EC3_epds[x]['category']['default_distance']

    dens = EC3_epds[x]['density']
    sdens = EC3_epds[x]['specific_density']

    unit = EC3_epds[x]['category']['declared_unit']
    lcia = list(EC3_epds[x]['pcr']['lcia_requirements'].keys())[0]
    


    material_data = {
        "material_id": 'to be assigned later',
        "display_name": EPDname,
        "source": none,
        "description": f'{desc},',
        #"validity": date_validity_ends_str,
        "reference_pcr": {
            "name": pcr_name,
            "id": pcr_id,
            "link": short_link
        },
        "thickness": {
            "qty": thckqty,
            "unit": thckU
        },
        "service_life": seLi,
        "waste_rate": none,
        "transportation": {
            "mode": tMode,
            "distance": dist
        },
        "density": {
            "qty": dens,
            "unit": none
        },
        "linear_density": {
            "qty": sdens,
            "unit": none
        },
        "declared_unit": unit,
        "lcia_method": lcia,
        "background_database": none,
        "impacts": {
            "gwp_total": {
                #"A1": A11, "A2": A12, "A3": A13, "A4": A14, "A5": A15, "C1": C11,
                #"C2": C12, "C3": C13, "C4": C14, "D": D1, "D1": D11, "D2": D12
            },
            "gwp_biogenic": {
                #"A1": A21, "A2": A22, "A3": A23, "A4": A24, "A5": A25, "C1": C21,
                #"C2": C22, "C3": C23, "C4": C24, "D": D2, "D1": D21, "D2": D22
            },
            "gwp_fossil": {
                #"A1": A31, "A2": A32, "A3": A33, "A4": A34, "A5": A35, "C1": C31,
                #"C2": C32, "C3": C33, "C4": C34, "D": D3, "D1": D31, "D2": D32
            },
            "gwp_iobc": {
                #"A1": A41, "A2": A42, "A3": A43, "A4": A44, "A5": A45, "C1": C41,
                #"C2": C42, "C3": C43, "C4": C44, "D": D4, "D1": D41, "D2": D42
            }
        },
        "characteristics": {}
    }
    
    EPDs.append(material_data)
    print(f'json #{x} is done')'''
# Out:
# successfully completed page 1
# '\n    xpdID = EC3_epds[x][\'open_xpd_uuid\']\n    response_impact = requests.get(impact_info_url+xpdID, headers=headers)\n    impact = response_impact.json()\n\n\n    ############################### DATA PATHS #################################\n    EPDname = EC3_epds[x][\'category\'][\'display_name\']\n    desc = EC3_epds[x][\'category\'][\'description\']\n    seLi = EC3_epds[x][\'reference_service_life\']\n    pcr_name = EC3_epds[x][\'pcr\'][\'name\']\n    pcr_id = EC3_epds[x][\'pcr\'][\'id\']\n    short_link = EC3_epds[x][\'pcr\'][\'short_link\']\n\n    thckqty = EC3_epds[x][\'thickness\']\n    thckU = EC3_epds[x][\'thickness_per_declared_unit\']\n\n    tMode = EC3_epds[x][\'category\'][\'default_transport_mode\']\n    dist = EC3_epds[x][\'category\'][\'default_distance\']\n\n    dens = EC3_epds[x][\'density\']\n    sdens = EC3_epds[x][\'specific_density\']\n\n    unit = EC3_epds[x][\'category\'][\'declared_unit\']\n    lcia = list(EC3_epds[x][\'pcr\'][\'lcia_requirements\'].keys())[0]\n    \n\n\n    material_data = {\n        "material_id": \'to be assigned later\',\n        "display_name": EPDname,\n        "source": none,\n        "description": f\'{desc},\',\n        #"validity": date_validity_ends_str,\n        "reference_pcr": {\n            "name": pcr_name,\n            "id": pcr_id,\n            "link": short_link\n        },\n        "thickness": {\n            "qty": thckqty,\n            "unit": thckU\n        },\n        "service_life": seLi,\n        "waste_rate": none,\n        "transportation": {\n            "mode": tMode,\n            "distance": dist\n        },\n        "density": {\n            "qty": dens,\n            "unit": none\n        },\n        "linear_density": {\n            "qty": sdens,\n            "unit": none\n        },\n        "declared_unit": unit,\n        "lcia_method": lcia,\n        "background_database": none,\n        "impacts": {\n            "gwp_total": {\n                #"A1": A11, "A2": A12, "A3": A13, "A4": A14, "A5": A15, "C1": C11,\n                #"C2": C12, "C3": C13, "C4": C14, "D": D1, "D1": D11, "D2": D12\n            },\n            "gwp_biogenic": {\n                #"A1": A21, "A2": A22, "A3": A23, "A4": A24, "A5": A25, "C1": C21,\n                #"C2": C22, "C3": C23, "C4": C24, "D": D2, "D1": D21, "D2": D22\n            },\n            "gwp_fossil": {\n                #"A1": A31, "A2": A32, "A3": A33, "A4": A34, "A5": A35, "C1": C31,\n                #"C2": C32, "C3": C33, "C4": C34, "D": D3, "D1": D31, "D2": D32\n            },\n            "gwp_iobc": {\n                #"A1": A41, "A2": A42, "A3": A43, "A4": A44, "A5": A45, "C1": C41,\n                #"C2": C42, "C3": C43, "C4": C44, "D": D4, "D1": D41, "D2": D42\n            }\n        },\n        "characteristics": {}\n    }\n    \n    EPDs.append(material_data)\n    print(f\'json #{x} is done\')'

# %%
len(product_epds)
# Out:
# 1

# %%
#epd_data[0]['open_xpd_uuid']
len(product_epd_ids)
product_epd_ids[0]
# Out:
# 'ec34u6kx'

# %%
import requests

impact_info_url = "https://openepd.buildingtransparency.org/api/epds/"+"ec36urza"

response_impact = requests.get(impact_info_url, headers=headers)
response_impact.json()
# Out:
# {'id': 'ec36urza',
#  'ref': 'https://openepd.buildingtransparency.org/api/epds/EC36URZA',
#  'ec3': {'uaGWP_a1a2a3_traci21': 437.8297093653758,
#   'uaGWP_a1a2a3_ar5': 439.1545751006035,
#   'category': 'Concrete >> Shotcrete',
#   'manufacturer_specific': True,
#   'plant_specific': True,
#   'product_specific': True,
#   'batch_specific': False,
#   'supply_chain_specificity': 0.0,
#   'original_data_format': 'pdf'},
#  'openepd_version': '0.1',
#  'doctype': 'OpenEPD',
#  'version': None,
#  'language': 'en',
#  'private': False,
#  'declaration_url': 'https://cqd.io/e/ec36urzas7',
#  'lca_discussion': '\n\n## Product Component Notes\ncrushed aggregate (ASTM C33), natural aggregate (ASTM C33), Portland cement (ASTM C150), slag cement (ASTM C989), fly ash (ASTM C618), admixture (ASTM C494), batch water (ASTM C1602)\n\n## LCA Notes\nTransportation: Transportation of these materials from supplier to the gate\nof the concrete producer.\nManufacturing (core processes): Energy used to store, batch, mix, and\ndistribute the concrete and operate the facility (concrete plant).\nWater use in mixing and distributing concrete.\nA summary of cradle-to-gate life cycle processes excluded from the EPD is as\nfollows:\n\nProduction, manufacture, and construction of buildings, capital goods, and\ninfrastructure.\nProduction and manufacture of concrete production equipment, concrete\ndelivery vehicles, earthmoving equipment, and laboratory equipment.\nPersonnel-related activities (travel, furniture, office supplies).\nEnergy and water use related to company management and sales\nactivities.\nA summary of the limitations of this EPD include the following:\n\nThis EPD does not report all of the environmental impacts due to\nmanufacturing of the product, but rather environmental impacts for\ncategories with established LCA-based methods to track and report.\nUnreported environmental impacts include (but are not limited to) factors\nattributable to human health, land use change, water use in the upstream\nmanufacturing process, and habitat destruction.\nThis EPD reports the results of an LCA for ‘cradle-to-gate’ analysis. Thus,\ndeclarations themselves are not comparative assertions, defined as an\nenvironmental claim regarding the superiority or equivalence of one\nproduct versus a competing product that performs the same function. An\nEPD does not make any statements that the product covered by the EPD\nis better or worse than any other product.\nIn order to assess the local impacts of product manufacturing, additional\nanalysis is required.\nLife cycle impact assessment results are relative expressions and do not\npredict impacts on category endpoints, the exceeding of thresholds,\nsafety margins, or risks.\nNote: The product manufacturer has the option of declaring additional information\nabout their product including conformance with any other sustainability certification\nprograms that often have performance and prescriptive requirements that aim to\nillustrate environmental best practices that cannot be captured by LCA.\n\nData quality, variability, and comparability\n\nThis EPD was created using plant-specific data for upstream materials. Potential\nvariations due to supplier locations, manufacturing processes, and efficiencies and\nfuel use are thus accounted for in this EPD. EPDs of concrete mixtures may not be\ncomparable if they do not comply with this standard and data from this EPD. While\nEPDs can be used to compare concrete mixes, the data cannot be used to compare\nbetween construction products or concrete mixes used in different concrete products\nunless the data is integrated into a comprehensive LCA. For example, precast\nconcrete, concrete masonry units, and site-cast concrete all have different\nmanufacturing processes whose impacts are attributed to different LCA stages. This\nprecludes direct comparison between mixes used in these different products until all\nlife cycle phases are included.\n\n## Source Data Notes\nPortland cement: Portland Concrete Association, Industry Average EPD,\n2016\nSlag cement: Slag Cement Association, industry average EPD, 2014\nFly ash: byproduct of  coal combustion; no upstream manufacturing\nimpacts\nSilica fume: byproduct of  silicon and ferrosilicon alloy production; no\nupstream manufacturing impacts\nAggregate (natural): US-EI: “Gravel, round, at mine/US”, 2001\nAggregate (crushed): US-EI process: “Gravel, crushed, at mine/US”,\n2001\nAggregate (lightweight): custom process, based on US-EI process:\n“Expanded clay, at plant/US”, 2000\nAggregate (recycled concrete): custo ...
#  'program_operator_doc_id': '',
#  'program_operator_version': None,
#  'third_party_verification_url': None,
#  'third_party_verifier_email': 'rita@iere.org',
#  'epd_developer_email': 'laurel.mcewen@climateearth.com',
#  'date_of_issue': '2016-10-27T00:00:00Z',
#  'valid_until': '2018-11-14T00:00:00Z',
#  'declared_unit': {'qty': 1, 'unit': 'm3'},
#  'kg_per_declared_unit': {'qty': 2400.0, 'unit': 'kg'},
#  'kg_C_per_declared_unit': None,
#  'product_name': 'Mix R50P18P1',
#  'product_sku': None,
#  'product_description': 'SHOT 5000 PSI 3/8" EF 3-5SL',
#  'product_image_small': None,
#  'product_image': 'https://cqddatastore.blob.core.windows.net/cqd/images/ccf2082ed7da4e13ae47eedf65b6322c.png',
#  'product_service_life_years': None,
#  'product_classes': {'EC3': 'Concrete >> Shotcrete',
#   'io.cqd.ec3': 'Concrete >> Shotcrete'},
#  'applicable_in': ['001'],
#  'product_usage_description': None,
#  'product_usage_image': None,
#  'manufacturing_description': None,
#  'manufacturing_image': None,
#  'impacts': {'TRACI 2.1': {'pocp': {'A1A2A3': {'mean': 45.0,
#      'unit': 'kgO3e',
#      'rsd': None,
#      'dist': 'log-normal'},
#     'A1': None,
#     'A2': None,
#     'A3': None,
#     'A4': None,
#     'A5': None,
#     'B1': None,
#     'B1_years': None,
#     'B2': None,
#     'B2_years': None,
#     'B3': None,
#     'B3_years': None,
#     'B4': None,
#     'B4_years': None,
#     'B5': None,
#     'B5_years': None,
#     'B6': None,
#     'B6_years': None,
#     'B7': None,
#     'B7_years': None,
#     'C1': None,
#     'C2': None,
#     'C3': None,
#     'C4': None,
#     'D': None,
#     'C_scenarios': None},
#    'ep-marine': {'A1A2A3': {'mean': 0.51,
#      'unit': 'kgNe',
#      'rsd': None,
#      'dist': 'log-normal'},
#     'A1': None,
#     'A2': None,
#     'A3': None,
#     'A4': None,
#     'A5': None,
#     'B1': None,
#     'B1_years': None,
#     'B2': None,
#     'B2_years': None,
#     'B3': None,
#     'B3_years': None,
#     'B4': None,
#     'B4_years': None,
#     'B5': None,
#     'B5_years': None,
#     'B6': None,
#     'B6_years': None,
#     'B7': None,
#     'B7_years': None,
#     'C1': None,
#     'C2': None,
#     'C3': None,
#     'C4': None,
#     'D': None,
#     'C_scenarios': None},
#    'gwp': {'A1A2A3': {'mean': 400.0,
#      'unit': 'kgCO2e',
#      'rsd': None,
#      'dist': 'log-normal'},
#     'A1': None,
#     'A2': None,
#     'A3': None,
#     'A4': None,
#     'A5': None,
#     'B1': None,
#     'B1_years': None,
#     'B2': None,
#     'B2_years': None,
#     'B3': None,
#     'B3_years': None,
#     'B4': None,
#     'B4_years': None,
#     'B5': None,
#     'B5_years': None,
#     'B6': None,
#     'B6_years': None,
#     'B7': None,
#     'B7_years': None,
#     'C1': None,
#     'C2': None,
#     'C3': None,
#     'C4': None,
#     'D': None,
#     'C_scenarios': None},
#    'ap': {'A1A2A3': {'mean': 1.94,
#      'unit': 'kgSO2e',
#      'rsd': None,
#      'dist': 'log-normal'},
#     'A1': None,
#     'A2': None,
#     'A3': None,
#     'A4': None,
#     'A5': None,
#     'B1': None,
#     'B1_years': None,
#     'B2': None,
#     'B2_years': None,
#     'B3': None,
#     'B3_years': None,
#     'B4': None,
#     'B4_years': None,
#     'B5': None,
#     'B5_years': None,
#     'B6': None,
#     'B6_years': None,
#     'B7': None,
#     'B7_years': None,
#     'C1': None,
#     'C2': None,
#     'C3': None,
#     'C4': None,
#     'D': None,
#     'C_scenarios': None},
#    'odp': {'A1A2A3': {'mean': 1.1e-05,
#      'unit': 'kgCFC11e',
#      'rsd': None,
#      'dist': 'log-normal'},
#     'A1': None,
#     'A2': None,
#     'A3': None,
#     'A4': None,
#     'A5': None,
#     'B1': None,
#     'B1_years': None,
#     'B2': None,
#     'B2_years': None,
#     'B3': None,
#     'B3_years': None,
#     'B4': None,
#     'B4_years': None,
#     'B5': None,
#     'B5_years': None,
#     'B6': None,
#     'B6_years': None,
#     'B7': None,
#     'B7_years': None,
#     'C1': None,
#     'C2': None,
#     'C3': None,
#     'C4': None,
#     'D': None,
#     'C_scenarios': None}}},
#  'resource_uses': {},
#  'output_flows': {},
#  'specs': {'concrete': {'strength_28d': '34.47378647 MPa',
#    'slump': '4 in',
#    'strength_other': None,
#    'strength_other_d': None,
#    'w_c_ratio': None,
#    'aci_exposure_classes': None,
#    'csa_exposure_classes': None,
#    'en_exposure_classes': None,
#    'application': {'fnd': None,
#     'sog': None,
#     'hrz': None,
#     'vrt_wall': None,
#     'vrt_column': None,
#     'vrt_other': None,
#     'sht': None,
#     'cdf': None,
#     'sac': None,
#     'pav': None,
#     'oil': None,
#     'grt': None,
#     'ota': None},
#    'options': {'lightweight': False,
#     'scc': False,
#     'finishable': None,
#     'air': False,
#     'co2': False,
#     'white': False,
#     'plc': False,
#     'fiber_reinforced': None},
#    'cementitious': {'opc': None,
#     'wht': None,
#     'ggbs': 0.0,
#     'gg45': None,
#     'mk': None,
#     'CaCO3': None,
#     'other': None,
#     'flyAsh': 0.0,
#     'siFume': None,
#     'natPoz': None}},
#   'Concrete': {'ext_version': '1.0',
#    'lightweight': False,
#    'strength_28d': '34.47378647 MPa',
#    'strength_other': None,
#    'strength_other_d': None,
#    'slump': '4 in',
#    'min_slump': '3 in',
#    'max_slump': '5 in',
#    'min_pipeline_size': '38.1 mm',
#    'w_c_ratio': None,
#    'air_entrain': False,
#    'co2_entrain': False,
#    'self_consolidating': False,
#    'white_cement': False,
#    'plc': False,
#    'finishable': None,
#    'fiber_reinforced': None,
#    'cementitious': {'opc': None,
#     'wht': None,
#     'ggbs': 0.0,
#     'flyAsh': 0.0,
#     'siFume': None,
#     'gg45': None,
#     'natPoz': None,
#     'mk': None,
#     'CaCO3': None,
#     'other': None},
#    'aggregate_size_max': '9.525 mm',
#    'cement_content': None,
#    'aci_exposure_classes': None,
#    'csa_exposure_classes': None,
#    'en_exposure_classes': None,
#    'typical_application': {'fnd': None,
#     'sog': None,
#     'hrz': None,
#     'vrt_wall': None,
#     'vrt_column': None,
#     'vrt_other': None,
#     'sht': None,
#     'cdf': None,
#     'sac': None,
#     'pav': None,
#     'oil': None,
#     'grt': None,
#     'ota': None},
#    'CementGrout': None,
#    'ConcretePaving': None,
#    'FlowableFill': None,
#    'OilPatch': None,
#    'ReadyMix': None,
#    'Shotcrete': {'ext_version': '1.0'}}},
#  'manufacturer': {'web_domain': 'centralconcrete.com',
#   'ref': 'https://openepd.buildingtransparency.org/api/orgs/centralconcrete.com',
#   'name': 'Central Concrete',
#   'alt_names': ['Central Concrete', 'Monumental Concrete', 'Centre Concrete']},
#  'plants': [{'id': '849VPJWC+F8.centralconcrete.com',
#    'name': 'Bode',
#    'ref': 'https://openepd.buildingtransparency.org/api/plants/849VPJWC+F8.centralconcrete.com',
#    'pluscode': '849VPJWC+F8',
#    'address': '450 Amador Street, San Francisco, CA 94124'}],
#  'program_operator': {'web_domain': 'iere.org',
#   'ref': 'https://openepd.buildingtransparency.org/api/orgs/iere.org',
#   'name': 'EarthSure',
#   'alt_names': ['Earthsure',
#    'IERE',
#    'Institute for Environmental Research and Education']},
#  'third_party_verifier': {'web_domain': 'iere.org',
#   'ref': 'https://openepd.buildingtransparency.org/api/orgs/iere.org',
#   'name': 'EarthSure',
#   'alt_names': ['Earthsure',
#    'IERE',
#    'Institute for Environmental Research and Education']},
#  'epd_developer': {'web_domain': 'climateearth.com',
#   'ref': 'https://openepd.buildingtransparency.org/api/orgs/climateearth.com',
#   'name': 'Climate Earth',
#   'alt_names': ['Climate Earth, Inc.',
#    'Climate Earth',
#    'carbonCLARITY Suite']},
#  'pcr': {'id': 'ec37zjz1',
#   'name': 'North American PCR for Concrete',
#   'ref': 'https://openepd.buildingtransparency.org/api/pcrs/EC37ZJZ1',
#   'issuer_doc_id': None,
#   'short_name': 'Concrete',
#   'version': '1.1',
#   'date_of_issue': '2013-12-04T00:00:00Z',
#   'valid_until': '2018-12-04T00:00:00Z',
#   'declared_units': [{'qty': 1, 'unit': 'm3'}],
#   'doc': 'https://app.box.com/file/292552692203',
#   'product_classes': {'EC3': ['Concrete'], 'io.cqd.ec3': ['Concrete']},
#   'status': 'Sunset'},
#  'compliance': [],
#  'attachments': {'TransparencyCatalogURL': 'https://transparencycatalog.com/company/central-concrete'},
#  'includes': None,
#  'alt_ids': {}}
